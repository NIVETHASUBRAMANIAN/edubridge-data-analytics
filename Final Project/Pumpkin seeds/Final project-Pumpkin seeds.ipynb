# %% [markdown]
# <h1 align="center">PUMPKIN SEEDS</h1>

# %% [raw]
# Pumpkin seeds are frequently consumed as confection worldwide because of their adequate amount of protein, fat, carbohydrate, and mineral contents. This study was carried out on the two most important and quality types of pumpkin seeds, ‘‘Urgup_Sivrisi’’ and ‘‘Cercevelik’’, generally grown in Urgup and Karacaoren regions in Turkey. However, morphological measurements of 2500 pumpkin seeds of both varieties were made possible by using the gray and binary forms of threshold techniques. Considering morphological features, all the data were modeled with five different machine learning methods: Logistic Regression (LR), Support Vector Machine (SVM) and Random Forest (RF), Decision Tree classifier and Naive Bayes.

# %% [markdown]
# ![shutterstock_229783426.jpg](attachment:shutterstock_229783426.jpg)

# %% [markdown]
# ## Problem Solving

# %% [raw]
# Fetching the details to identify the varities of seeds.

# %% [markdown]
# ## Reference

# %% [raw]
# https://www.kaggle.com/datasets/muratkokludataset/pumpkin-seeds-dataset

# %% [markdown]
# ### Functions:
# - STEP 1:Importing Libraries
# - STEP 2:Reading and Preparing the dataset
# - STEP 3:Exploring the data
# - STEP 4:Cleaning the data
# - STEP 5:Exracting the data
# - STEP 6:Visualizing the data
# - STEP 7:Creating a model
# - STEP 8:Conclusion

# %% [markdown]
# ## STEP 1:Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## STEP 2:Reading and Preparing the dataset

# %% [markdown]
# ### Read the data

# %%
d=pd.read_excel('Pumpkin_Seeds_Dataset.xlsx')

# %% [markdown]
# ### View the data

# %%
d
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0     56276    888.242           326.1485           220.2388        56831
# 1     76631   1068.146           417.1932           234.2289        77280
# 2     71623   1082.987           435.8328           211.0457        72663
# 3     66458    992.051           381.5638           222.5322        67118
# 4     66107    998.146           383.8883           220.4545        67117
# ...     ...        ...                ...                ...          ...
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# 1           312.3614        0.8275    0.9916  0.7151     0.8440
# 2           301.9822        0.8749    0.9857  0.7400     0.7674
# 3           290.8899        0.8123    0.9902  0.7396     0.8486
# 4           290.1207        0.8187    0.9850  0.6752     0.8338
# ...              ...           ...       ...     ...        ...
# 2495        318.4289        0.9340    0.9907  0.4888     0.6672
# 2496        297.7874        0.9101    0.9919  0.6002     0.7444
# 2497        334.7199        0.8990    0.9920  0.7643     0.7549
# 2498        319.1758        0.9130    0.9890  0.7374     0.7185
# 2499        328.8485        0.8621    0.9901  0.7360     0.7933
#
#       Aspect_Ration  Compactness          Class
# 0            1.4809       0.8207     Çerçevelik
# 1            1.7811       0.7487     Çerçevelik
# 2            2.0651       0.6929     Çerçevelik
# 3            1.7146       0.7624     Çerçevelik
# 4            1.7413       0.7557     Çerçevelik
# ...             ...          ...            ...
# 2495         2.7996       0.5973  Ürgüp Sivrisi
# 2496         2.4134       0.6433  Ürgüp Sivrisi
# 2497         2.2828       0.6599  Ürgüp Sivrisi
# 2498         2.4513       0.6359  Ürgüp Sivrisi
# 2499         1.9735       0.7104  Ürgüp Sivrisi
#
# [2500 rows x 13 columns]

# %% [markdown]
# ## STEP 3:Exploring the data

# %% [markdown]
# ### To check how many rows and columns

# %%
d.shape
# Out:
# (2500, 13)

# %% [markdown]
# ### Column names

# %%
d.columns
# Out:
# Index(['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length',
#        'Convex_Area', 'Equiv_Diameter', 'Eccentricity', 'Solidity', 'Extent',
#        'Roundness', 'Aspect_Ration', 'Compactness', 'Class'],
#       dtype='object')

# %% [markdown]
# ### Top 5 datas

# %%
d.head()
# Out:
#     Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0  56276    888.242           326.1485           220.2388        56831
# 1  76631   1068.146           417.1932           234.2289        77280
# 2  71623   1082.987           435.8328           211.0457        72663
# 3  66458    992.051           381.5638           222.5322        67118
# 4  66107    998.146           383.8883           220.4545        67117
#
#    Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  Aspect_Ration  \
# 0        267.6805        0.7376    0.9902  0.7453     0.8963         1.4809
# 1        312.3614        0.8275    0.9916  0.7151     0.8440         1.7811
# 2        301.9822        0.8749    0.9857  0.7400     0.7674         2.0651
# 3        290.8899        0.8123    0.9902  0.7396     0.8486         1.7146
# 4        290.1207        0.8187    0.9850  0.6752     0.8338         1.7413
#
#    Compactness       Class
# 0       0.8207  Çerçevelik
# 1       0.7487  Çerçevelik
# 2       0.6929  Çerçevelik
# 3       0.7624  Çerçevelik
# 4       0.7557  Çerçevelik

# %% [markdown]
# ### Bottom 5 datas

# %%
d.tail()
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 2495        318.4289        0.9340    0.9907  0.4888     0.6672
# 2496        297.7874        0.9101    0.9919  0.6002     0.7444
# 2497        334.7199        0.8990    0.9920  0.7643     0.7549
# 2498        319.1758        0.9130    0.9890  0.7374     0.7185
# 2499        328.8485        0.8621    0.9901  0.7360     0.7933
#
#       Aspect_Ration  Compactness          Class
# 2495         2.7996       0.5973  Ürgüp Sivrisi
# 2496         2.4134       0.6433  Ürgüp Sivrisi
# 2497         2.2828       0.6599  Ürgüp Sivrisi
# 2498         2.4513       0.6359  Ürgüp Sivrisi
# 2499         1.9735       0.7104  Ürgüp Sivrisi

# %% [markdown]
# ### Information of data

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               2500 non-null   int64
#  1   Perimeter          2500 non-null   float64
#  2   Major_Axis_Length  2500 non-null   float64
#  3   Minor_Axis_Length  2500 non-null   float64
#  4   Convex_Area        2500 non-null   int64
#  5   Equiv_Diameter     2500 non-null   float64
#  6   Eccentricity       2500 non-null   float64
#  7   Solidity           2500 non-null   float64
#  8   Extent             2500 non-null   float64
#  9   Roundness          2500 non-null   float64
#  10  Aspect_Ration      2500 non-null   float64
#  11  Compactness        2500 non-null   float64
#  12  Class              2500 non-null   object
# dtypes: float64(10), int64(2), object(1)
# memory usage: 254.0+ KB

# %% [markdown]
# ### Datatypes

# %%
d.dtypes
# Out:
# Area                   int64
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length    float64
# Convex_Area            int64
# Equiv_Diameter       float64
# Eccentricity         float64
# Solidity             float64
# Extent               float64
# Roundness            float64
# Aspect_Ration        float64
# Compactness          float64
# Class                 object
# dtype: object

# %% [markdown]
# ### Statistical information

# %%
d.describe().transpose()
# Out:
#                     count          mean           std         min  \
# Area               2500.0  80658.220800  13664.510228  47939.0000
# Perimeter          2500.0   1130.279015    109.256418    868.4850
# Major_Axis_Length  2500.0    456.601840     56.235704    320.8446
# Minor_Axis_Length  2500.0    225.794921     23.297245    152.1718
# Convex_Area        2500.0  81508.084400  13764.092788  48366.0000
# Equiv_Diameter     2500.0    319.334230     26.891920    247.0584
# Eccentricity       2500.0      0.860879      0.045167      0.4921
# Solidity           2500.0      0.989492      0.003494      0.9186
# Extent             2500.0      0.693205      0.060914      0.4680
# Roundness          2500.0      0.791533      0.055924      0.5546
# Aspect_Ration      2500.0      2.041702      0.315997      1.1487
# Compactness        2500.0      0.704121      0.053067      0.5608
#
#                             25%          50%           75%          max
# Area               70765.000000  79076.00000  89757.500000  136574.0000
# Perimeter           1048.829750   1123.67200   1203.340500    1559.4500
# Major_Axis_Length    414.957850    449.49660    492.737650     661.9113
# Minor_Axis_Length    211.245925    224.70310    240.672875     305.8180
# Convex_Area        71512.000000  79872.00000  90797.750000  138384.0000
# Equiv_Diameter       300.167975    317.30535    338.057375     417.0029
# Eccentricity           0.831700      0.86370      0.897025       0.9481
# Solidity               0.988300      0.99030      0.991500       0.9944
# Extent                 0.658900      0.71305      0.740225       0.8296
# Roundness              0.751900      0.79775      0.834325       0.9396
# Aspect_Ration          1.801050      1.98420      2.262075       3.1444
# Compactness            0.663475      0.70770      0.743500       0.9049

# %% [markdown]
# ### Correlation of dataset

# %%
d.corr()
# Out:
#                        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# Area               1.000000   0.928548           0.789133           0.685304
# Perimeter          0.928548   1.000000           0.946181           0.392913
# Major_Axis_Length  0.789133   0.946181           1.000000           0.099376
# Minor_Axis_Length  0.685304   0.392913           0.099376           1.000000
# Convex_Area        0.999806   0.929971           0.789061           0.685634
# Equiv_Diameter     0.998464   0.928055           0.787078           0.690020
# Eccentricity       0.159624   0.464601           0.704287          -0.590877
# Solidity           0.158388   0.065340           0.119291           0.090915
# Extent            -0.014018  -0.140600          -0.214990           0.233576
# Roundness         -0.149378  -0.500968          -0.684972           0.558566
# Aspect_Ration      0.159960   0.487880           0.729156          -0.598475
# Compactness       -0.160438  -0.484440          -0.726958           0.603441
#
#                    Convex_Area  Equiv_Diameter  Eccentricity  Solidity  \
# Area                  0.999806        0.998464      0.159624  0.158388
# Perimeter             0.929971        0.928055      0.464601  0.065340
# Major_Axis_Length     0.789061        0.787078      0.704287  0.119291
# Minor_Axis_Length     0.685634        0.690020     -0.590877  0.090915
# Convex_Area           1.000000        0.998289      0.159156  0.139178
# Equiv_Diameter        0.998289        1.000000      0.156246  0.159454
# Eccentricity          0.159156        0.156246      1.000000  0.043991
# Solidity              0.139178        0.159454      0.043991  1.000000
# Extent               -0.015449       -0.010970     -0.327316  0.067537
# Roundness            -0.153615       -0.145313     -0.890651  0.200836
# Aspect_Ration         0.159822        0.155762      0.950225  0.026410
# Compactness          -0.160432       -0.156411     -0.981689 -0.019967
#
#                      Extent  Roundness  Aspect_Ration  Compactness
# Area              -0.014018  -0.149378       0.159960    -0.160438
# Perimeter         -0.140600  -0.500968       0.487880    -0.484440
# Major_Axis_Length -0.214990  -0.684972       0.729156    -0.726958
# Minor_Axis_Length  0.233576   0.558566      -0.598475     0.603441
# Convex_Area       -0.015449  -0.153615       0.159822    -0.160432
# Equiv_Diameter    -0.010970  -0.145313       0.155762    -0.156411
# Eccentricity      -0.327316  -0.890651       0.950225    -0.981689
# Solidity           0.067537   0.200836       0.026410    -0.019967
# Extent             1.000000   0.352338      -0.329933     0.336984
# Roundness          0.352338   1.000000      -0.935233     0.933308
# Aspect_Ration     -0.329933  -0.935233       1.000000    -0.990778
# Compactness        0.336984   0.933308      -0.990778     1.000000

# %% [markdown]
# ### Covariance of dataset

# %%
d.cov()
# Out:
#                            Area     Perimeter  Major_Axis_Length  \
# Area               1.867188e+08  1.386263e+06      606396.330928
# Perimeter          1.386263e+06  1.193696e+04        5813.439727
# Major_Axis_Length  6.063963e+05  5.813440e+03        3162.454399
# Minor_Axis_Length  2.181635e+05  1.000111e+03         130.196132
# Convex_Area        1.880431e+08  1.398505e+06      610759.811433
# Equiv_Diameter     3.669005e+05  2.726732e+03        1190.287441
# Eccentricity       9.851830e+01  2.292727e+00           1.788904
# Solidity           7.561186e+00  2.494004e-02           0.023436
# Extent            -1.166796e+01 -9.357199e-01          -0.736454
# Roundness         -1.141503e+02 -3.060937e+00          -2.154184
# Aspect_Ration      6.906983e+02  1.684392e+01          12.957324
# Compactness       -1.163391e+02 -2.808732e+00          -2.169426
#
#                    Minor_Axis_Length   Convex_Area  Equiv_Diameter  \
# Area                   218163.548708  1.880431e+08   366900.493499
# Perimeter                1000.111416  1.398505e+06     2726.732433
# Major_Axis_Length         130.196132  6.107598e+05     1190.287441
# Minor_Axis_Length         542.761605  2.198590e+05      432.303032
# Convex_Area            219858.997462  1.894503e+08   369509.406203
# Equiv_Diameter            432.303032  3.695094e+05      723.175347
# Eccentricity               -0.621766  9.894570e+01        0.189782
# Solidity                    0.007400  6.692539e+00        0.014981
# Extent                      0.331473 -1.295306e+01       -0.017970
# Roundness                   0.727740 -1.182436e+02       -0.218537
# Aspect_Ration              -4.405890  6.951302e+02        1.323632
# Compactness                 0.746042 -1.171822e+02       -0.223210
#
#                    Eccentricity  Solidity     Extent   Roundness  \
# Area                  98.518300  7.561186 -11.667960 -114.150338
# Perimeter              2.292727  0.024940  -0.935720   -3.060937
# Major_Axis_Length      1.788904  0.023436  -0.736454   -2.154184
# Minor_Axis_Length     -0.621766  0.007400   0.331473    0.727740
# Convex_Area           98.945700  6.692539 -12.953059 -118.243642
# Equiv_Diameter         0.189782  0.014981  -0.017970   -0.218537
# Eccentricity           0.002040  0.000007  -0.000901   -0.002250
# Solidity               0.000007  0.000012   0.000014    0.000039
# Extent                -0.000901  0.000014   0.003710    0.001200
# Roundness             -0.002250  0.000039   0.001200    0.003127
# Aspect_Ration          0.013562  0.000029  -0.006351   -0.016527
# Compactness           -0.002353 -0.000004   0.001089    0.002770
#
#                    Aspect_Ration  Compactness
# Area                  690.698280  -116.339138
# Perimeter              16.843920    -2.808732
# Major_Axis_Length      12.957324    -2.169426
# Minor_Axis_Length      -4.405890     0.746042
# Convex_Area           695.130182  -117.182219
# Equiv_Diameter          1.323632    -0.223210
# Eccentricity            0.013562    -0.002353
# Solidity                0.000029    -0.000004
# Extent                 -0.006351     0.001089
# Roundness              -0.016527     0.002770
# Aspect_Ration           0.099854    -0.016614
# Compactness            -0.016614     0.002816

# %% [markdown]
# ## STEP 4:Cleaning the data

# %% [markdown]
# ### To check is there any null values

# %%
d.isnull().sum()
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %% [markdown]
# ### To check is there any duplicated

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## STEP 5:Exracting the data

# %% [markdown]
# ### Unique values

# %%
d.nunique()
# Out:
# Area                 2424
# Perimeter            2490
# Major_Axis_Length    2499
# Minor_Axis_Length    2497
# Convex_Area          2445
# Equiv_Diameter       2424
# Eccentricity         1295
# Solidity              166
# Extent               1392
# Roundness            1480
# Aspect_Ration        2237
# Compactness          1405
# Class                   2
# dtype: int64

# %% [markdown]
# ### Unique value for class

# %%
d['Class'].unique()
# Out:
# array(['Çerçevelik', 'Ürgüp Sivrisi'], dtype=object)

# %% [markdown]
# ### Class value counts

# %%
d['Class'].value_counts()
# Out:
# Çerçevelik       1300
# Ürgüp Sivrisi    1200
# Name: Class, dtype: int64

# %% [markdown]
# ## STEP 6:Visualizing the data

# %% [markdown]
# ### Piechart for Class

# %%
plt.title('Class',fontsize=20)
d['Class'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ### Countplot for Class

# %%
sns.countplot(x='Class',data=d,palette='tab10')
plt.show()

# %% [markdown]
# ### Heatmap

# %%
n_data=['Area','Perimeter','Major_Axis_Length','Minor_Axis_Length']
plt.figure(figsize=(10,5))
sns.heatmap(d[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %%
d.hist(bins=20 ,figsize=(20,15),color='blue')
plt.show()

# %% [markdown]
# ## STEP 7:Creating a model

# %% [markdown]
# - Target(Class)
# - Features (Area,Perimeter,Major_Axis_Length,Minor_Axis_Length,Convex_Area,Equiv_Diameter,Eccentricity,Solidity,Extent,Roundness,Aspect_Ration,Compactness).

# %%
x=d.drop(['Class'],axis=1)

# %%
x
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0     56276    888.242           326.1485           220.2388        56831
# 1     76631   1068.146           417.1932           234.2289        77280
# 2     71623   1082.987           435.8328           211.0457        72663
# 3     66458    992.051           381.5638           222.5322        67118
# 4     66107    998.146           383.8883           220.4545        67117
# ...     ...        ...                ...                ...          ...
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# 1           312.3614        0.8275    0.9916  0.7151     0.8440
# 2           301.9822        0.8749    0.9857  0.7400     0.7674
# 3           290.8899        0.8123    0.9902  0.7396     0.8486
# 4           290.1207        0.8187    0.9850  0.6752     0.8338
# ...              ...           ...       ...     ...        ...
# 2495        318.4289        0.9340    0.9907  0.4888     0.6672
# 2496        297.7874        0.9101    0.9919  0.6002     0.7444
# 2497        334.7199        0.8990    0.9920  0.7643     0.7549
# 2498        319.1758        0.9130    0.9890  0.7374     0.7185
# 2499        328.8485        0.8621    0.9901  0.7360     0.7933
#
#       Aspect_Ration  Compactness
# 0            1.4809       0.8207
# 1            1.7811       0.7487
# 2            2.0651       0.6929
# 3            1.7146       0.7624
# 4            1.7413       0.7557
# ...             ...          ...
# 2495         2.7996       0.5973
# 2496         2.4134       0.6433
# 2497         2.2828       0.6599
# 2498         2.4513       0.6359
# 2499         1.9735       0.7104
#
# [2500 rows x 12 columns]

# %%
y=d.Class

# %%
y
# Out:
# 0          Çerçevelik
# 1          Çerçevelik
# 2          Çerçevelik
# 3          Çerçevelik
# 4          Çerçevelik
#             ...
# 2495    Ürgüp Sivrisi
# 2496    Ürgüp Sivrisi
# 2497    Ürgüp Sivrisi
# 2498    Ürgüp Sivrisi
# 2499    Ürgüp Sivrisi
# Name: Class, Length: 2500, dtype: object

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Splitting the dataset:
# - test_size = 0.25 so that data is split into 75% and 25%
# - random_state is applied so that each time we run we get the same result

# %% [markdown]
# ### Model Creation

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2)

# %%
x_train.shape
# Out:
# (1875, 12)

# %%
x_test.shape
# Out:
# (625, 12)

# %%
y_train.shape
# Out:
# (1875,)

# %%
y_test.shape
# Out:
# (625,)

# %% [markdown]
# #### Training the data with Some of the ML approaches:
# - Logistic Regression
# - Decision Tree Classifier
# - Random Forest Classifier
# - Naive Bayes

# %% [markdown]
# ### Logistic Regression

# %%
plt.xlabel("Area")
plt.ylabel("Class")
plt.scatter(d.Area,d.Class,marker="*",color="green")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_l= LogisticRegression()

# %%
model_l.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model_l.score(x_train,y_train)
# Out:
# 0.8741333333333333

# %%
model_l.score(x_test,y_test)
# Out:
# 0.8864

# %%
y_predict=model_l.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
print('The Testing Accuracy of the algorithm is ', accuracy_score(y_test, y_predict))
# Out:
# The Testing Accuracy of the algorithm is  0.8864

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
perfomance=confusion_matrix(y_test,y_predict)
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model,x_test,y_test)
plt.show()

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report
performance_report=classification_report(y_test,y_predict)
print(performance_report)
# Out:
#                precision    recall  f1-score   support
#
#    Çerçevelik       0.87      0.92      0.89       321
# Ürgüp Sivrisi       0.91      0.85      0.88       304
#
#      accuracy                           0.89       625
#     macro avg       0.89      0.89      0.89       625
#  weighted avg       0.89      0.89      0.89       625

# %% [markdown]
# ### Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_d=model=DecisionTreeClassifier()

# %%
model_d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_d.score(x_test,y_test)
# Out:
# 0.848

# %%
y_predict=model_d.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
print('The Testing Accuracy of the algorithm is ', accuracy_score(y_test, y_predict))
# Out:
# The Testing Accuracy of the algorithm is  0.848

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
perfomance=confusion_matrix(y_test,y_predict)
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model,x_test,y_test)
plt.show()

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report
performance_report=classification_report(y_test,y_predict)
print(performance_report)
# Out:
#                precision    recall  f1-score   support
#
#    Çerçevelik       0.85      0.85      0.85       321
# Ürgüp Sivrisi       0.84      0.84      0.84       304
#
#      accuracy                           0.85       625
#     macro avg       0.85      0.85      0.85       625
#  weighted avg       0.85      0.85      0.85       625

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_r=RandomForestClassifier()

# %%
model_r.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
model_r.score(x_test,y_test)
# Out:
# 1.0

# %%
y_predict=model_r.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
print('The Testing Accuracy of the algorithm is ', accuracy_score(y_test, y_predict))
# Out:
# The Testing Accuracy of the algorithm is  1.0

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
perfomance=confusion_matrix(y_test,y_predict)
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model_r,x_test,y_test)
plt.show()

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report
performance_report=classification_report(y_test,y_predict)
print(performance_report)
# Out:
#                precision    recall  f1-score   support
#
#    Çerçevelik       1.00      1.00      1.00       321
# Ürgüp Sivrisi       1.00      1.00      1.00       304
#
#      accuracy                           1.00       625
#     macro avg       1.00      1.00      1.00       625
#  weighted avg       1.00      1.00      1.00       625

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_N=GaussianNB()

# %%
model_N.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model_N.score(x_test,y_test)
# Out:
# 0.7984

# %%
y_predict=model_N.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
print('The Testing Accuracy of the algorithm is ', accuracy_score(y_test, y_predict))
# Out:
# The Testing Accuracy of the algorithm is  0.7984

# %%
from sklearn.metrics import confusion_matrix
perfomance=confusion_matrix(y_test,y_predict)
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model_N,x_test,y_test)
plt.show()

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report
performance_report=classification_report(y_test,y_predict)
print(performance_report)
# Out:
#                precision    recall  f1-score   support
#
#    Çerçevelik       0.76      0.89      0.82       321
# Ürgüp Sivrisi       0.86      0.70      0.77       304
#
#      accuracy                           0.80       625
#     macro avg       0.81      0.80      0.80       625
#  weighted avg       0.81      0.80      0.80       625

# %% [markdown]
# ## STEP 8:Conclusion

# %%
results = pd.DataFrame(columns = [ 'Testing Accuracy Base Model'],index = ['Logistic Regression', 'Decision Tree Classifier', 'Random Forest Classifier', 'Naive Bayes'])

# %%
results.loc['Logistic Regression'] = model_l.score(x_test,y_test) ;
results.loc['Decision Tree Classifier'] = model_d.score(x_test,y_test);
results.loc['Random Forest Classifier'] = model_r.score(x_test,y_test);
results.loc['Naive Bayes'] = model_N.score(x_test,y_test);

# %%
results
# Out:
#                          Testing Accuracy Base Model
# Logistic Regression                           0.8864
# Decision Tree Classifier                       0.848
# Random Forest Classifier                         1.0
# Naive Bayes                                   0.7984

# %% [markdown]
# I have achieved good accuracy in <b> Random Forest Algorithm </b>
